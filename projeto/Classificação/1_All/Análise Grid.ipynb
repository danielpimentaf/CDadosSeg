# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=False)
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
data = pd.read_csv('/content/drive/MyDrive/UFPR/aplicacao_ciencia_dados/trabalho_disciplina/classificação/1/1_All/cv_grid.csv')

# %%
data.head()
# Out:
#    mean_fit_time  ...  rank_test_matthews_corrcoef
# 0       0.331768  ...                          216
# 1       0.670970  ...                          212
# 2       1.318004  ...                          205
# 3       3.284892  ...                          199
# 4       0.328067  ...                          306
#
# [5 rows x 36 columns]

# %%
data.sort_values(by=['rank_test_f1_score'], inplace=True, ignore_index=True)

# %%
data['params'][0]
# Out:
# "{'bootstrap': False, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}"

# %%
data.loc[0]
# Out:
# mean_fit_time                                                             0.915742
# std_fit_time                                                            0.00632162
# mean_score_time                                                          0.0629836
# std_score_time                                                           0.0004735
# param_bootstrap                                                              False
# param_criterion                                                            entropy
# param_max_depth                                                                NaN
# param_max_features                                                            sqrt
# param_min_samples_leaf                                                           1
# param_min_samples_split                                                          2
# param_n_estimators                                                             100
# params                           {'bootstrap': False, 'criterion': 'entropy', '...
# split0_test_f1_score                                                      0.973631
# split1_test_f1_score                                                      0.973993
# split2_test_f1_score                                                       0.97665
# split3_test_f1_score                                                       0.97491
# split4_test_f1_score                                                      0.971545
# mean_test_f1_score                                                        0.974146
# std_test_f1_score                                                       0.00166785
# rank_test_f1_score                                                               1
# split0_test_accuracy_score                                                0.970605
# split1_test_accuracy_score                                                 0.97117
# split2_test_accuracy_score                                                0.973997
# split3_test_accuracy_score                                                0.972301
# split4_test_accuracy_score                                                0.968326
# mean_test_accuracy_score                                                   0.97128
# std_test_accuracy_score                                                 0.00187708
# rank_test_accuracy_score                                                         1
# split0_test_matthews_corrcoef                                             0.940489
# split1_test_matthews_corrcoef                                             0.941654
# split2_test_matthews_corrcoef                                             0.947377
# split3_test_matthews_corrcoef                                             0.944027
# split4_test_matthews_corrcoef                                             0.935871
# mean_test_matthews_corrcoef                                               0.941883
# std_test_matthews_corrcoef                                              0.00381883
# rank_test_matthews_corrcoef                                                      1
# Name: 0, dtype: object
