# %%
#liberando Drive
from google.colab import drive
drive.mount('/content/drive', force_remount=False)
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_validate
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import matthews_corrcoef
from sklearn.metrics import make_scorer

# %%
path_dataset = '/content/drive/My Drive/UFPR/aplicacao_ciencia_dados/trabalho_disciplina/dataset/training_dataset.csv'
data = pd.read_csv(path_dataset)

# %%
X = data[data.columns[:-1]]
y = data[data.columns[-1:]]

# %%
X_selec = X[['Prefix_Suffix', 'having_Sub_Domain', 'SSLfinal_State', 'Request_URL', 'URL_of_Anchor', 'Links_in_tags', 'SFH', 'web_traffic', 'Page_Rank', 'Google_Index']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_selec, y, test_size=0.2, random_state=42)

# %%
skf = StratifiedKFold(n_splits=5)

# %% [markdown]
# #RandomForest

# %%
model_random = RandomForestClassifier()

# %%
result_random = cross_validate(model_random, X_train, y_train, scoring={'f1_score' : make_scorer(f1_score),'accuracy_score': make_scorer(accuracy_score),'matthews_corrcoef':make_scorer(matthews_corrcoef)}, cv=skf, n_jobs=-1)

# %%
pd_result_random=pd.DataFrame(result_random)

# %%
pd_result_random
# Out:
#    fit_time  score_time  ...  test_accuracy_score  test_matthews_corrcoef
# 0  0.587067    0.055335  ...             0.942906                0.884522
# 1  0.586274    0.054400  ...             0.943471                0.885547
# 2  0.578415    0.051798  ...             0.947428                0.893544
# 3  0.593213    0.053294  ...             0.956473                0.911956
# 4  0.363259    0.034351  ...             0.946267                0.891174
#
# [5 rows x 5 columns]

# %%
pd_result_random.mean()
# Out:
# fit_time                  0.541645
# score_time                0.049835
# test_f1_score             0.952671
# test_accuracy_score       0.947309
# test_matthews_corrcoef    0.893349
# dtype: float64

# %% [markdown]
# #Logistic

# %%
model_logistic = LogisticRegression()

# %%
result_logistic = cross_validate(model_logistic, X_train, y_train, scoring={'f1_score' : make_scorer(f1_score),'accuracy_score': make_scorer(accuracy_score),'matthews_corrcoef':make_scorer(matthews_corrcoef)}, cv=skf, n_jobs=-1)

# %%
pd_result_logistic = pd.DataFrame(result_logistic)

# %%
pd_result_logistic
# Out:
#    fit_time  score_time  ...  test_accuracy_score  test_matthews_corrcoef
# 0  0.058232    0.008931  ...             0.919163                0.836359
# 1  0.046644    0.009250  ...             0.912380                0.822651
# 2  0.034511    0.009697  ...             0.921990                0.842555
# 3  0.037106    0.009173  ...             0.925382                0.848977
# 4  0.024580    0.005419  ...             0.930995                0.860275
#
# [5 rows x 5 columns]

# %%
pd_result_logistic.mean()
# Out:
# fit_time                  0.040214
# score_time                0.008494
# test_f1_score             0.930683
# test_accuracy_score       0.921982
# test_matthews_corrcoef    0.842164
# dtype: float64

# %% [markdown]
# #Linear SVM

# %%
model_svm = LinearSVC()

# %%
result_svm = cross_validate(model_svm, X_train, y_train, scoring={'f1_score' : make_scorer(f1_score),'accuracy_score': make_scorer(accuracy_score),'matthews_corrcoef':make_scorer(matthews_corrcoef)}, cv=skf, n_jobs=-1)

# %%
pd_result_svm = pd.DataFrame(result_svm)

# %%
pd_result_svm
# Out:
#    fit_time  score_time  ...  test_accuracy_score  test_matthews_corrcoef
# 0  0.107571    0.008848  ...             0.920294                0.838581
# 1  0.103646    0.009004  ...             0.915772                0.829609
# 2  0.105686    0.008799  ...             0.921425                0.841516
# 3  0.102606    0.008696  ...             0.928208                0.854706
# 4  0.057620    0.005429  ...             0.930430                0.859114
#
# [5 rows x 5 columns]

# %%
pd_result_svm.mean()
# Out:
# fit_time                  0.095426
# score_time                0.008155
# test_f1_score             0.931840
# test_accuracy_score       0.923226
# test_matthews_corrcoef    0.844705
# dtype: float64
