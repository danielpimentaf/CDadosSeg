# %%
#liberando Drive
from google.colab import drive
drive.mount('/content/drive', force_remount=False)
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_validate
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import matthews_corrcoef
from sklearn.metrics import make_scorer

# %%
path_dataset = '/content/drive/My Drive/UFPR/aplicacao_ciencia_dados/trabalho_disciplina/dataset/training_dataset.csv'
data = pd.read_csv(path_dataset)

# %%
X = data[data.columns[:-1]]
y = data[data.columns[-1:]]

# %%
X_2 = X[['Redirect', 'on_mouseover', 'RightClick', 'popUpWidnow', 'Iframe']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_2, y, test_size=0.2, random_state=42)

# %%
skf = StratifiedKFold(n_splits=5)

# %% [markdown]
# #RandomForest

# %%
model_random = RandomForestClassifier()

# %%
result_random = cross_validate(model_random, X_train, y_train, scoring={'f1_score' : make_scorer(f1_score),'accuracy_score': make_scorer(accuracy_score),'matthews_corrcoef':make_scorer(matthews_corrcoef)}, cv=skf, n_jobs=-1)

# %%
pd_result_random=pd.DataFrame(result_random)

# %%
pd_result_random
# Out:
#    fit_time  score_time  ...  test_accuracy_score  test_matthews_corrcoef
# 0  0.419836    0.039153  ...             0.570944                0.117471
# 1  0.417182    0.040742  ...             0.574901                0.133664
# 2  0.421591    0.041137  ...             0.570379                0.122276
# 3  0.402664    0.041163  ...             0.564161                0.081133
# 4  0.257258    0.029379  ...             0.555995                0.036791
#
# [5 rows x 5 columns]

# %%
pd_result_random.mean()
# Out:
# fit_time                  0.383706
# score_time                0.038315
# test_f1_score             0.714688
# test_accuracy_score       0.567276
# test_matthews_corrcoef    0.098267
# dtype: float64

# %% [markdown]
# #Logistic

# %%
model_logistic = LogisticRegression()

# %%
result_logistic = cross_validate(model_logistic, X_train, y_train, scoring={'f1_score' : make_scorer(f1_score),'accuracy_score': make_scorer(accuracy_score),'matthews_corrcoef':make_scorer(matthews_corrcoef)}, cv=skf, n_jobs=-1)

# %%
pd_result_logistic = pd.DataFrame(result_logistic)

# %%
pd_result_logistic
# Out:
#    fit_time  score_time  ...  test_accuracy_score  test_matthews_corrcoef
# 0  0.036602    0.009221  ...             0.554551                0.033651
# 1  0.030344    0.009309  ...             0.566987                0.081517
# 2  0.028558    0.008750  ...             0.568118                0.090031
# 3  0.028964    0.009691  ...             0.553985                0.031591
# 4  0.018908    0.005048  ...             0.549208                0.004334
#
# [5 rows x 5 columns]

# %%
pd_result_logistic.mean()
# Out:
# fit_time                  0.028675
# score_time                0.008404
# test_f1_score             0.703560
# test_accuracy_score       0.558570
# test_matthews_corrcoef    0.048225
# dtype: float64

# %% [markdown]
# #Linear SVM

# %%
model_svm = LinearSVC()

# %%
result_svm = cross_validate(model_svm, X_train, y_train, scoring={'f1_score' : make_scorer(f1_score),'accuracy_score': make_scorer(accuracy_score),'matthews_corrcoef':make_scorer(matthews_corrcoef)}, cv=skf, n_jobs=-1)

# %%
pd_result_svm = pd.DataFrame(result_svm)

# %%
pd_result_svm
# Out:
#    fit_time  score_time  ...  test_accuracy_score  test_matthews_corrcoef
# 0  0.095755    0.008633  ...             0.554551                0.033651
# 1  0.091550    0.008963  ...             0.566987                0.081517
# 2  0.096608    0.008578  ...             0.568118                0.090031
# 3  0.093794    0.009004  ...             0.553985                0.031591
# 4  0.053879    0.005266  ...             0.549208                0.004334
#
# [5 rows x 5 columns]

# %%
pd_result_svm.mean()
# Out:
# fit_time                  0.086317
# score_time                0.008089
# test_f1_score             0.703560
# test_accuracy_score       0.558570
# test_matthews_corrcoef    0.048225
# dtype: float64
