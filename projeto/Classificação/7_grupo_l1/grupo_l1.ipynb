# %%
#liberando Drive
from google.colab import drive
drive.mount('/content/drive', force_remount=False)
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_validate
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import matthews_corrcoef
from sklearn.metrics import make_scorer

# %%
path_dataset = '/content/drive/My Drive/UFPR/aplicacao_ciencia_dados/trabalho_disciplina/dataset/training_dataset.csv'
data = pd.read_csv(path_dataset)

# %%
X = data[data.columns[:-1]]
y = data[data.columns[-1:]]

# %%
X_l1 = X[['Prefix_Suffix', 'having_Sub_Domain', 'SSLfinal_State', 'Request_URL','URL_of_Anchor', 'Links_in_tags', 'SFH', 'web_traffic', 'Google_Index']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_l1, y, test_size=0.2, random_state=42)

# %%
skf = StratifiedKFold(n_splits=5)

# %% [markdown]
# #RandomForest

# %%
model_random = RandomForestClassifier()

# %%
result_random = cross_validate(model_random, X_train, y_train, scoring={'f1_score' : make_scorer(f1_score),'accuracy_score': make_scorer(accuracy_score),'matthews_corrcoef':make_scorer(matthews_corrcoef)}, cv=skf, n_jobs=-1)

# %%
pd_result_random=pd.DataFrame(result_random)

# %%
pd_result_random
# Out:
#    fit_time  score_time  ...  test_accuracy_score  test_matthews_corrcoef
# 0  0.570142    0.053721  ...             0.937253                0.873182
# 1  0.600754    0.051340  ...             0.935557                0.870104
# 2  0.620821    0.050925  ...             0.946297                0.891284
# 3  0.550501    0.050446  ...             0.948559                0.896022
# 4  0.411263    0.032845  ...             0.944005                0.886588
#
# [5 rows x 5 columns]

# %%
pd_result_random.mean()
# Out:
# fit_time                  0.550696
# score_time                0.047855
# test_f1_score             0.948334
# test_accuracy_score       0.942334
# test_matthews_corrcoef    0.883436
# dtype: float64

# %% [markdown]
# #Logistic

# %%
model_logistic = LogisticRegression()

# %%
result_logistic = cross_validate(model_logistic, X_train, y_train, scoring={'f1_score' : make_scorer(f1_score),'accuracy_score': make_scorer(accuracy_score),'matthews_corrcoef':make_scorer(matthews_corrcoef)}, cv=skf, n_jobs=-1)

# %%
pd_result_logistic = pd.DataFrame(result_logistic)

# %%
pd_result_logistic
# Out:
#    fit_time  score_time  ...  test_accuracy_score  test_matthews_corrcoef
# 0  0.048607    0.008196  ...             0.919163                0.836323
# 1  0.040878    0.008750  ...             0.911815                0.821572
# 2  0.033174    0.009421  ...             0.921425                0.841366
# 3  0.032670    0.009967  ...             0.926512                0.851313
# 4  0.024422    0.005183  ...             0.930995                0.860275
#
# [5 rows x 5 columns]

# %%
pd_result_logistic.mean()
# Out:
# fit_time                  0.035950
# score_time                0.008304
# test_f1_score             0.930729
# test_accuracy_score       0.921982
# test_matthews_corrcoef    0.842170
# dtype: float64

# %% [markdown]
# #Linear SVM

# %%
model_svm = LinearSVC()

# %%
result_svm = cross_validate(model_svm, X_train, y_train, scoring={'f1_score' : make_scorer(f1_score),'accuracy_score': make_scorer(accuracy_score),'matthews_corrcoef':make_scorer(matthews_corrcoef)}, cv=skf, n_jobs=-1)

# %%
pd_result_svm = pd.DataFrame(result_svm)

# %%
pd_result_svm
# Out:
#    fit_time  score_time  ...  test_accuracy_score  test_matthews_corrcoef
# 0  0.091769    0.008695  ...             0.922555                0.843134
# 1  0.095687    0.008621  ...             0.915206                0.828484
# 2  0.087319    0.009129  ...             0.920859                0.840403
# 3  0.085278    0.008744  ...             0.928208                0.854706
# 4  0.054480    0.005517  ...             0.930430                0.859114
#
# [5 rows x 5 columns]

# %%
pd_result_svm.mean()
# Out:
# fit_time                  0.082906
# score_time                0.008141
# test_f1_score             0.932076
# test_accuracy_score       0.923452
# test_matthews_corrcoef    0.845168
# dtype: float64
