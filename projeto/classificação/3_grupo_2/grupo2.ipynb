# %%
#liberando Drive
from google.colab import drive
drive.mount('/content/drive', force_remount=False)
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_validate
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import matthews_corrcoef
from sklearn.metrics import make_scorer

# %%
path_dataset = '/content/drive/My Drive/UFPR/aplicacao_ciencia_dados/trabalho_disciplina/dataset/training_dataset.csv'
data = pd.read_csv(path_dataset)

# %%
X = data[data.columns[:-1]]
y = data[data.columns[-1:]]

# %%
X_3 = X[['Request_URL', 'URL_of_Anchor', 'Links_in_tags', 'SFH', 'Submitting_to_email', 'Abnormal_URL']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_3, y, test_size=0.2, random_state=42)

# %%
skf = StratifiedKFold(n_splits=5)

# %% [markdown]
# #RandomForest

# %%
model_random = RandomForestClassifier()

# %%
result_random = cross_validate(model_random, X_train, y_train, scoring={'f1_score' : make_scorer(f1_score),'accuracy_score': make_scorer(accuracy_score),'matthews_corrcoef':make_scorer(matthews_corrcoef)}, cv=skf, n_jobs=-1)

# %%
pd_result_random=pd.DataFrame(result_random)

# %%
pd_result_random
# Out:
#    fit_time  score_time  ...  test_accuracy_score  test_matthews_corrcoef
# 0  0.488979    0.062569  ...             0.880158                0.761565
# 1  0.495608    0.054059  ...             0.854720                0.708630
# 2  0.483584    0.078704  ...             0.870548                0.745207
# 3  0.477182    0.056973  ...             0.882419                0.767440
# 4  0.318832    0.033287  ...             0.869344                0.735013
#
# [5 rows x 5 columns]

# %%
pd_result_random.mean()
# Out:
# fit_time                  0.452837
# score_time                0.057118
# test_f1_score             0.890296
# test_accuracy_score       0.871438
# test_matthews_corrcoef    0.743571
# dtype: float64

# %% [markdown]
# #Logistic

# %%
model_logistic = LogisticRegression()

# %%
result_logistic = cross_validate(model_logistic, X_train, y_train, scoring={'f1_score' : make_scorer(f1_score),'accuracy_score': make_scorer(accuracy_score),'matthews_corrcoef':make_scorer(matthews_corrcoef)}, cv=skf, n_jobs=-1)

# %%
pd_result_logistic = pd.DataFrame(result_logistic)

# %%
pd_result_logistic
# Out:
#    fit_time  score_time  ...  test_accuracy_score  test_matthews_corrcoef
# 0  0.033843    0.008807  ...             0.862069                0.720777
# 1  0.026369    0.008934  ...             0.856981                0.717116
# 2  0.024462    0.009847  ...             0.864330                0.732291
# 3  0.028277    0.010327  ...             0.857547                0.711676
# 4  0.019113    0.005776  ...             0.855204                0.706749
#
# [5 rows x 5 columns]

# %%
pd_result_logistic.mean()
# Out:
# fit_time                  0.026413
# score_time                0.008738
# test_f1_score             0.878645
# test_accuracy_score       0.859226
# test_matthews_corrcoef    0.717722
# dtype: float64

# %% [markdown]
# #Linear SVM

# %%
model_svm = LinearSVC()

# %%
result_svm = cross_validate(model_svm, X_train, y_train, scoring={'f1_score' : make_scorer(f1_score),'accuracy_score': make_scorer(accuracy_score),'matthews_corrcoef':make_scorer(matthews_corrcoef)}, cv=skf, n_jobs=-1)

# %%
pd_result_svm = pd.DataFrame(result_svm)

# %%
pd_result_svm
# Out:
#    fit_time  score_time  ...  test_accuracy_score  test_matthews_corrcoef
# 0  0.081224    0.009068  ...             0.859808                0.716078
# 1  0.083408    0.009260  ...             0.855285                0.713931
# 2  0.080201    0.009130  ...             0.860938                0.725948
# 3  0.078842    0.008458  ...             0.852459                0.701581
# 4  0.045434    0.005439  ...             0.872172                0.745419
#
# [5 rows x 5 columns]

# %%
pd_result_svm.mean()
# Out:
# fit_time                  0.073822
# score_time                0.008271
# test_f1_score             0.881101
# test_accuracy_score       0.860133
# test_matthews_corrcoef    0.720591
# dtype: float64
