# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=False)
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
data = pd.read_csv('/content/drive/MyDrive/UFPR/aplicacao_ciencia_dados/trabalho_disciplina/classificação/1/8_grupotree/cv_grid.csv')

# %%
data.head()
# Out:
#    mean_fit_time  ...  rank_test_matthews_corrcoef
# 0       0.249570  ...                          261
# 1       0.476649  ...                          205
# 2       0.945093  ...                          265
# 3       2.362114  ...                          196
# 4       0.238957  ...                          136
#
# [5 rows x 36 columns]

# %%
data.sort_values(by=['rank_test_f1_score'], inplace=True, ignore_index=True)

# %%
data['params'][0]
# Out:
# "{'bootstrap': True, 'criterion': 'gini', 'max_depth': 50, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 16, 'n_estimators': 50}"

# %%
data.loc[0]
# Out:
# mean_fit_time                                                             0.237258
# std_fit_time                                                            0.00815638
# mean_score_time                                                          0.0281295
# std_score_time                                                         0.000115121
# param_bootstrap                                                               True
# param_criterion                                                               gini
# param_max_depth                                                                 50
# param_max_features                                                            sqrt
# param_min_samples_leaf                                                           1
# param_min_samples_split                                                         16
# param_n_estimators                                                              50
# params                           {'bootstrap': True, 'criterion': 'gini', 'max_...
# split0_test_f1_score                                                      0.948058
# split1_test_f1_score                                                      0.936973
# split2_test_f1_score                                                      0.946054
# split3_test_f1_score                                                      0.953101
# split4_test_f1_score                                                      0.936747
# mean_test_f1_score                                                        0.944187
# std_test_f1_score                                                       0.00640843
# rank_test_f1_score                                                               1
# split0_test_accuracy_score                                                0.941775
# split1_test_accuracy_score                                                0.928208
# split2_test_accuracy_score                                                0.938949
# split3_test_accuracy_score                                                0.947428
# split4_test_accuracy_score                                                0.928733
# mean_test_accuracy_score                                                  0.937019
# std_test_accuracy_score                                                 0.00749639
# rank_test_accuracy_score                                                         2
# split0_test_matthews_corrcoef                                             0.882093
# split1_test_matthews_corrcoef                                             0.855314
# split2_test_matthews_corrcoef                                             0.876836
# split3_test_matthews_corrcoef                                             0.893624
# split4_test_matthews_corrcoef                                             0.855768
# mean_test_matthews_corrcoef                                               0.872727
# std_test_matthews_corrcoef                                               0.0150474
# rank_test_matthews_corrcoef                                                      2
# Name: 0, dtype: object
