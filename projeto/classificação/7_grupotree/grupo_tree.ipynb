# %%
#liberando Drive
from google.colab import drive
drive.mount('/content/drive', force_remount=False)
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_validate
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import matthews_corrcoef
from sklearn.metrics import make_scorer

# %%
path_dataset = '/content/drive/My Drive/UFPR/aplicacao_ciencia_dados/trabalho_disciplina/dataset/training_dataset.csv'
data = pd.read_csv(path_dataset)

# %%
X = data[data.columns[:-1]]
y = data[data.columns[-1:]]

# %%
X_tree = X[['Prefix_Suffix', 'having_Sub_Domain', 'SSLfinal_State', 'URL_of_Anchor','Links_in_tags', 'web_traffic']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_tree, y, test_size=0.2, random_state=42)

# %%
skf = StratifiedKFold(n_splits=5)

# %% [markdown]
# #RandomForest

# %%
model_random = RandomForestClassifier()

# %%
result_random = cross_validate(model_random, X_train, y_train, scoring={'f1_score' : make_scorer(f1_score),'accuracy_score': make_scorer(accuracy_score),'matthews_corrcoef':make_scorer(matthews_corrcoef)}, cv=skf, n_jobs=-1)

# %%
pd_result_random=pd.DataFrame(result_random)

# %%
pd_result_random
# Out:
#    fit_time  score_time  ...  test_accuracy_score  test_matthews_corrcoef
# 0  0.513399    0.047447  ...             0.936122                0.870636
# 1  0.505100    0.046564  ...             0.928208                0.855314
# 2  0.486633    0.048130  ...             0.938949                0.876905
# 3  0.514222    0.048271  ...             0.946297                0.891358
# 4  0.303886    0.031036  ...             0.928733                0.855734
#
# [5 rows x 5 columns]

# %%
pd_result_random.mean()
# Out:
# fit_time                  0.464648
# score_time                0.044290
# test_f1_score             0.942996
# test_accuracy_score       0.935662
# test_matthews_corrcoef    0.869989
# dtype: float64

# %% [markdown]
# #Logistic

# %%
model_logistic = LogisticRegression()

# %%
result_logistic = cross_validate(model_logistic, X_train, y_train, scoring={'f1_score' : make_scorer(f1_score),'accuracy_score': make_scorer(accuracy_score),'matthews_corrcoef':make_scorer(matthews_corrcoef)}, cv=skf, n_jobs=-1)

# %%
pd_result_logistic = pd.DataFrame(result_logistic)

# %%
pd_result_logistic
# Out:
#    fit_time  score_time  ...  test_accuracy_score  test_matthews_corrcoef
# 0  0.042032    0.009202  ...             0.910684                0.819315
# 1  0.037700    0.008366  ...             0.906727                0.811035
# 2  0.036441    0.008611  ...             0.914641                0.827264
# 3  0.031221    0.008451  ...             0.916902                0.831648
# 4  0.019673    0.005319  ...             0.923643                0.845299
#
# [5 rows x 5 columns]

# %%
pd_result_logistic.mean()
# Out:
# fit_time                  0.033413
# score_time                0.007990
# test_f1_score             0.923717
# test_accuracy_score       0.914519
# test_matthews_corrcoef    0.826912
# dtype: float64

# %% [markdown]
# #Linear SVM

# %%
model_svm = LinearSVC()

# %%
result_svm = cross_validate(model_svm, X_train, y_train, scoring={'f1_score' : make_scorer(f1_score),'accuracy_score': make_scorer(accuracy_score),'matthews_corrcoef':make_scorer(matthews_corrcoef)}, cv=skf, n_jobs=-1)

# %%
pd_result_svm = pd.DataFrame(result_svm)

# %%
pd_result_svm
# Out:
#    fit_time  score_time  ...  test_accuracy_score  test_matthews_corrcoef
# 0  0.075985    0.008528  ...             0.916337                0.830453
# 1  0.061710    0.008661  ...             0.906162                0.810155
# 2  0.059926    0.008414  ...             0.914641                0.828101
# 3  0.059932    0.008571  ...             0.919729                0.837694
# 4  0.036047    0.005425  ...             0.923643                0.845401
#
# [5 rows x 5 columns]

# %%
pd_result_svm.mean()
# Out:
# fit_time                  0.058720
# score_time                0.007920
# test_f1_score             0.925873
# test_accuracy_score       0.916102
# test_matthews_corrcoef    0.830361
# dtype: float64
