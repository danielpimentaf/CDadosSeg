# %%
#liberando Drive
from google.colab import drive
drive.mount('/content/drive', force_remount=False)
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_validate
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import matthews_corrcoef
from sklearn.metrics import make_scorer

# %%
path_dataset = '/content/drive/My Drive/UFPR/aplicacao_ciencia_dados/trabalho_disciplina/dataset/training_dataset.csv'
data = pd.read_csv(path_dataset)

# %%
X = data[data.columns[:-1]]
y = data[data.columns[-1:]]

# %%
X_1 = X[['age_of_domain', 'DNSRecord', 'web_traffic', 'Page_Rank','Google_Index', 'Links_pointing_to_page', 'Statistical_report']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_1, y, test_size=0.2, random_state=42)

# %%
skf = StratifiedKFold(n_splits=5)

# %%
model = RandomForestClassifier()

# %%
result = cross_validate(model, X_train, y_train, scoring={'f1_score' : make_scorer(f1_score),'accuracy_score': make_scorer(accuracy_score),'matthews_corrcoef':make_scorer(matthews_corrcoef)}, cv=skf, n_jobs=-1)

# %%
pd_result=pd.DataFrame(result)

# %%
pd_result
# Out:
#    fit_time  score_time  ...  test_accuracy_score  test_matthews_corrcoef
# 0  0.505898    0.051396  ...             0.758055                0.509387
# 1  0.518916    0.050721  ...             0.728660                0.447116
# 2  0.513067    0.055622  ...             0.741097                0.473153
# 3  0.528999    0.053543  ...             0.729226                0.448261
# 4  0.306029    0.033468  ...             0.735294                0.460803
#
# [5 rows x 5 columns]

# %%
pd_result.mean()
# Out:
# fit_time                  0.474582
# score_time                0.048950
# test_f1_score             0.773944
# test_accuracy_score       0.738466
# test_matthews_corrcoef    0.467744
# dtype: float64
