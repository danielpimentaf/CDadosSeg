# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=False)
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
data = pd.read_csv('/content/drive/MyDrive/UFPR/aplicacao_ciencia_dados/trabalho_disciplina/classificação/1/6_grupo_selec/cv_grid.csv')

# %%
data.head()
# Out:
#    mean_fit_time  ...  rank_test_matthews_corrcoef
# 0       0.287054  ...                          186
# 1       0.560085  ...                          196
# 2       1.094603  ...                          181
# 3       2.735388  ...                          166
# 4       0.266648  ...                          253
#
# [5 rows x 36 columns]

# %%
data.sort_values(by=['rank_test_f1_score'], inplace=True, ignore_index=True)

# %%
data['params'][0]
# Out:
# "{'bootstrap': True, 'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}"

# %%
data.loc[0]
# Out:
# mean_fit_time                                                               1.1658
# std_fit_time                                                            0.00652071
# mean_score_time                                                           0.096454
# std_score_time                                                            0.001075
# param_bootstrap                                                               True
# param_criterion                                                               gini
# param_max_depth                                                                NaN
# param_max_features                                                            auto
# param_min_samples_leaf                                                           1
# param_min_samples_split                                                          2
# param_n_estimators                                                             200
# ...
